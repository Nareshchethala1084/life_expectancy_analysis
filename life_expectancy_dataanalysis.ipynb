# %%
import pandas as pd

# %%
path_cle = input('Please input the file path to country life Expectancy file:')
dfcle = pd.read_csv(path_cle)
#change the path as per you local repository
# Out:
# Please input the file path to country life Expectancy file: /Users/nareshchethala/Desktop/BAIM-601/Datasets_BAIM-601/countryLifeExpectancy.csv

# %% [markdown]
# /Users/nareshchethala/Desktop/BAIM-601/Datasets_BAIM-601/countryLifeExpectancy.csv

# %%
display(dfcle)
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
dfcle = dfcle.drop('continent', axis=1)
display(dfcle)
# Out:
#           country  year         pop  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0   28.801  779.445314
# 1     Afghanistan  1957   9240934.0   30.332  820.853030
# 2     Afghanistan  1962  10267083.0   31.997  853.100710
# 3     Afghanistan  1967  11537966.0   34.020  836.197138
# 4     Afghanistan  1972  13079460.0   36.088  739.981106
# ...           ...   ...         ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
path_cc = input('Please input the file path to CountryContinent file:')
dfcc = pd.read_csv(path_cc)
#change the path as per your local repository
display(dfcc)
# Out:
# Please input the file path to CountryContinent file: /Users/nareshchethala/Desktop/BAIM-601/Datasets_BAIM-601/CountryContinent.csv
#          country       continent
# 0    Afghanistan             Asia
# 1        Albania           Europe
# 2        Algeria       Africa
# 3        Andorra         Europe
# 4         Angola           Africa
# ..           ...              ...
# 191    Venezuela  South America
# 192      Vietnam          Asia
# 193        Yemen          Asia
# 194       Zambia         Africa
# 195     Zimbabwe           Africa
#
# [196 rows x 2 columns]

# %% [markdown]
# /Users/nareshchethala/Desktop/BAIM-601/Datasets_BAIM-601/CountryContinent.csv

# %%
import pandas as pd

# Get dataframe names as input from the user
df1_name = input('Please enter the dataframe name of Country Life Expectancy:')
df2_name = input('Please enter the dataframe name of Country Continent:')

# Load the DataFrames based on user input
try:
    df1 = globals()[df1_name]  # Assuming df1_name is the variable name of the DataFrame
    df2 = globals()[df2_name]  # Assuming df2_name is the variable name of the DataFrame
except KeyError:
    print("Error: One or both of the dataframe names entered is incorrect.")
    exit()

# Merge the dataframes
merge_file = pd.merge(df1, df2)

# Get user input for the merged dataframe name
merged_name = input('Please enter the name for the merged dataframe: ')

# Assign the merged dataframe to a variable with the user-provided name
globals()[merged_name] = merge_file  # Creates a variable with the user-provided name

# Display the merged dataframe
print(globals()[merged_name])
# Out:
# Please enter the dataframe name of Country Life Expectancy: dfcle
# Please enter the dataframe name of Country Continent: dfcc
# Please enter the name for the merged dataframe:  df_merged
#           country  year         pop  lifeExp   gdpPercap continent
# 0     Afghanistan  1952   8425333.0   28.801  779.445314       Asia
# 1     Afghanistan  1957   9240934.0   30.332  820.853030       Asia
# 2     Afghanistan  1962  10267083.0   31.997  853.100710       Asia
# 3     Afghanistan  1967  11537966.0   34.020  836.197138       Asia
# 4     Afghanistan  1972  13079460.0   36.088  739.981106       Asia
# ...           ...   ...         ...      ...         ...        ...
# 1531     Zimbabwe  1987   9216418.0   62.351  706.157306     Africa
# 1532     Zimbabwe  1992  10704340.0   60.377  693.420786     Africa
# 1533     Zimbabwe  1997  11404948.0   46.809  792.449960     Africa
# 1534     Zimbabwe  2002  11926563.0   39.989  672.038623     Africa
# 1535     Zimbabwe  2007  12311143.0   43.487  469.709298     Africa
#
# [1536 rows x 6 columns]

# %%
# Strip leading/trailing whitespace and standardize the case
df_merged['continent '] = df_merged['continent '].str.strip().str.title()
df_merged
# Out:
#           country  year         pop  lifeExp   gdpPercap continent
# 0     Afghanistan  1952   8425333.0   28.801  779.445314       Asia
# 1     Afghanistan  1957   9240934.0   30.332  820.853030       Asia
# 2     Afghanistan  1962  10267083.0   31.997  853.100710       Asia
# 3     Afghanistan  1967  11537966.0   34.020  836.197138       Asia
# 4     Afghanistan  1972  13079460.0   36.088  739.981106       Asia
# ...           ...   ...         ...      ...         ...        ...
# 1531     Zimbabwe  1987   9216418.0   62.351  706.157306     Africa
# 1532     Zimbabwe  1992  10704340.0   60.377  693.420786     Africa
# 1533     Zimbabwe  1997  11404948.0   46.809  792.449960     Africa
# 1534     Zimbabwe  2002  11926563.0   39.989  672.038623     Africa
# 1535     Zimbabwe  2007  12311143.0   43.487  469.709298     Africa
#
# [1536 rows x 6 columns]

# %%
df_merged.rename(columns={'continent ': 'continent'}, inplace=True)

# %%
# Print all column names in the DataFrame
print(df_merged.columns)
# Out:
# Index(['country', 'year', 'pop', 'lifeExp', 'gdpPercap', 'continent'], dtype='object')

# %%
#optional, use this only if you want to save the merged dataframe as csv
#if you want to run it seperately then replace 'globals()[merged_name]' with name of your dataframe
globals()[merged_name].to_csv('/Users/nareshchethala/Desktop/BAIM-601/Datasets_BAIM-601/dfmerge.csv')
#Please change the loaction path and also file name as per your requirements

# %% [markdown]
# Now in terminal change the directory to the dfmerged file and run the following code to directly open it in excel
# open -a 'Microsoft Excel' dfmerged.csv

# %%
#in the place of df_merged use the file name you have used
df_merged.describe()
# Out:
#               year           pop      lifeExp      gdpPercap
# count  1536.000000  1.536000e+03  1536.000000    1536.000000
# mean   1979.500000  3.001478e+07    59.270369    7162.607324
# std      17.265884  1.101132e+08    12.958851    9986.804081
# min    1952.000000  6.001100e+04    23.599000     298.846212
# 25%    1965.750000  2.829359e+06    48.066750    1135.131982
# 50%    1979.500000  7.226422e+06    60.386500    3430.729002
# 75%    1993.250000  1.980510e+07    70.783750    9241.571834
# max    2007.000000  1.318683e+09    82.603000  113523.132900

# %%
# Drop the second occurrence of the 'continent' column
#df_merged = df_merged.drop(df_merged.columns[df_merged.columns.get_loc('continent') + 1], axis=1)

# Alternatively, if you specifically know the order of columns and just need to drop the last one
# df = df.loc[:,~df.columns.duplicated(keep='first')]

#print(df_merged.head())

# %%
import matplotlib.pyplot as plt

max_population = df_merged.groupby('country')['year'].idxmax()

df_max = df_merged.loc[max_population]

print(df_max)
# Out:
#           country  year         pop  lifeExp     gdpPercap      continent
# 11    Afghanistan  2007  31889923.0   43.828    974.580338           Asia
# 23        Albania  2007   3600523.0   76.423   5937.029526         Europe
# 35        Algeria  2007  33333216.0   72.301   6223.367465         Africa
# 47         Angola  2007  12420476.0   42.731   4797.231267         Africa
# 59      Argentina  2007  40301927.0   75.320  12779.379640  South America
# ...           ...   ...         ...      ...           ...            ...
# 1487      Uruguay  2007   3447496.0   76.384  10611.462990  South America
# 1499    Venezuela  2007  26084662.0   73.747  11415.805690  South America
# 1511      Vietnam  2007  85262356.0   74.249   2441.576404           Asia
# 1523       Zambia  2007  11746035.0   42.384   1271.211593         Africa
# 1535     Zimbabwe  2007  12311143.0   43.487    469.709298         Africa
#
# [128 rows x 6 columns]

# %%
# Sorting and selecting the top 20
top_20 = df_max.sort_values(by='pop', ascending=False).head(20)
print(top_20)
# Out:
#              country  year           pop  lifeExp     gdpPercap      continent
# 299            China  2007  1.318683e+09   72.961   4959.114854           Asia
# 647            India  2007  1.110396e+09   64.698   2452.210407           Asia
# 659        Indonesia  2007  2.235470e+08   70.650   3540.651564           Asia
# 179           Brazil  2007  1.900106e+08   72.390   9065.800825  South America
# 1091        Pakistan  2007  1.692706e+08   65.483   2605.947580           Asia
# 107       Bangladesh  2007  1.504483e+08   64.062   1391.253792           Asia
# 1055         Nigeria  2007  1.350312e+08   46.859   2013.977305         Africa
# 743            Japan  2007  1.274680e+08   82.603  31656.068060           Asia
# 911           Mexico  2007  1.087009e+08   76.195  11977.574960  North America
# 1139     Philippines  2007  9.107729e+07   71.688   3190.481016           Asia
# 1511         Vietnam  2007  8.526236e+07   74.249   2441.576404           Asia
# 527          Germany  2007  8.240100e+07   79.406  32170.374420         Europe
# 419            Egypt  2007  8.026454e+07   71.338   5581.180998         Africa
# 467         Ethiopia  2007  7.651189e+07   52.947    690.805576         Africa
# 1451          Turkey  2007  7.115865e+07   71.777   8458.276384    Asia/Europe
# 671             Iran  2007  6.945357e+07   70.964  11605.714490           Asia
# 1403        Thailand  2007  6.506815e+07   70.616   7458.396327           Asia
# 491           France  2007  6.108392e+07   80.657  30470.016700         Europe
# 1475  United Kingdom  2007  6.077624e+07   79.425  33203.261280         Europe
# 719            Italy  2007  5.814773e+07   80.546  28569.719700         Europe

# %%
top_20_lle = df_max.sort_values(by='lifeExp', ascending=True).head(20)
print(top_20)
# Out:
#              country  year           pop  lifeExp     gdpPercap      continent
# 299            China  2007  1.318683e+09   72.961   4959.114854           Asia
# 647            India  2007  1.110396e+09   64.698   2452.210407           Asia
# 659        Indonesia  2007  2.235470e+08   70.650   3540.651564           Asia
# 179           Brazil  2007  1.900106e+08   72.390   9065.800825  South America
# 1091        Pakistan  2007  1.692706e+08   65.483   2605.947580           Asia
# 107       Bangladesh  2007  1.504483e+08   64.062   1391.253792           Asia
# 1055         Nigeria  2007  1.350312e+08   46.859   2013.977305         Africa
# 743            Japan  2007  1.274680e+08   82.603  31656.068060           Asia
# 911           Mexico  2007  1.087009e+08   76.195  11977.574960  North America
# 1139     Philippines  2007  9.107729e+07   71.688   3190.481016           Asia
# 1511         Vietnam  2007  8.526236e+07   74.249   2441.576404           Asia
# 527          Germany  2007  8.240100e+07   79.406  32170.374420         Europe
# 419            Egypt  2007  8.026454e+07   71.338   5581.180998         Africa
# 467         Ethiopia  2007  7.651189e+07   52.947    690.805576         Africa
# 1451          Turkey  2007  7.115865e+07   71.777   8458.276384    Asia/Europe
# 671             Iran  2007  6.945357e+07   70.964  11605.714490           Asia
# 1403        Thailand  2007  6.506815e+07   70.616   7458.396327           Asia
# 491           France  2007  6.108392e+07   80.657  30470.016700         Europe
# 1475  United Kingdom  2007  6.077624e+07   79.425  33203.261280         Europe
# 719            Italy  2007  5.814773e+07   80.546  28569.719700         Europe

# %%
top_20_lle.set_index('country')['lifeExp'].plot(kind = 'bar', color = 'red')
plt.title('Top 20 Countries in lowest lifeExp')
plt.xlabel('Country')
plt.ylabel('Life Expectancy')
plt.xticks(rotation=90)
plt.show()

# %%
top_20_hle = df_max.sort_values(by='lifeExp', ascending = True).head(20)
print(top_20)
# Out:
#              country  year           pop  lifeExp     gdpPercap      continent
# 299            China  2007  1.318683e+09   72.961   4959.114854           Asia
# 647            India  2007  1.110396e+09   64.698   2452.210407           Asia
# 659        Indonesia  2007  2.235470e+08   70.650   3540.651564           Asia
# 179           Brazil  2007  1.900106e+08   72.390   9065.800825  South America
# 1091        Pakistan  2007  1.692706e+08   65.483   2605.947580           Asia
# 107       Bangladesh  2007  1.504483e+08   64.062   1391.253792           Asia
# 1055         Nigeria  2007  1.350312e+08   46.859   2013.977305         Africa
# 743            Japan  2007  1.274680e+08   82.603  31656.068060           Asia
# 911           Mexico  2007  1.087009e+08   76.195  11977.574960  North America
# 1139     Philippines  2007  9.107729e+07   71.688   3190.481016           Asia
# 1511         Vietnam  2007  8.526236e+07   74.249   2441.576404           Asia
# 527          Germany  2007  8.240100e+07   79.406  32170.374420         Europe
# 419            Egypt  2007  8.026454e+07   71.338   5581.180998         Africa
# 467         Ethiopia  2007  7.651189e+07   52.947    690.805576         Africa
# 1451          Turkey  2007  7.115865e+07   71.777   8458.276384    Asia/Europe
# 671             Iran  2007  6.945357e+07   70.964  11605.714490           Asia
# 1403        Thailand  2007  6.506815e+07   70.616   7458.396327           Asia
# 491           France  2007  6.108392e+07   80.657  30470.016700         Europe
# 1475  United Kingdom  2007  6.077624e+07   79.425  33203.261280         Europe
# 719            Italy  2007  5.814773e+07   80.546  28569.719700         Europe

# %%
top_20.set_index('country')['pop'].plot(kind='bar', color='skyblue')
plt.title('Latest Year Population by Country')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(rotation=90)  # Rotates country names for better readability
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(top_20['pop'], top_20['lifeExp'], color='blue', alpha=0.5)

# Calculating the Correlation using linear regression y = mx + b
x = top_20['pop']
y = top_20['lifeExp']
m, b = np.polyfit(x, y, 1)  # m = slope, b = intercept

# Adding the trend line to the plot
plt.plot(x, m*x + b, color='red', label='Trend Line')

# adding title, labels and legend
plt.title('Population vs Life Expectancy')
plt.xlabel('Population')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.legend()

# Showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering for the latest year data for each country
idx_year = df_merged.groupby('country')['year'].idxmax()
latest_data = df_merged.loc[idx_year]

# Aggregating total population by continent
continent_population = latest_data.groupby('continent')['pop'].sum()
print(continent_population)
# Out:
# continent
# Africa           8.411878e+08
# Asia             3.706397e+09
# Asia/Europe      7.115865e+07
# Europe           4.992636e+08
# North America    2.152150e+08
# Oceania          2.454995e+07
# South America    3.785738e+08
# Name: pop, dtype: float64

# %%
df_merged['continent'].describe()
# Out:
# count       1536
# unique         7
# top       Africa
# freq         564
# Name: continent, dtype: object

# %%
# Plotting the data
plt.figure(figsize=(10, 6))
continent_population.plot(kind='bar', color='skyblue')
plt.title('Total Population by Continent in the Latest Year')
plt.xlabel('Continent')
plt.ylabel('Total Population')
plt.xticks(rotation=0)  # Keep the continent names horizontal for readability
plt.show()

# %%
# Aggregating total population by continent
continent_lifeexp = latest_data.groupby('continent')['lifeExp'].mean()
print(continent_population)
# Out:
# continent
# Africa           8.411878e+08
# Asia             3.706397e+09
# Asia/Europe      7.115865e+07
# Europe           4.992636e+08
# North America    2.152150e+08
# Oceania          2.454995e+07
# South America    3.785738e+08
# Name: pop, dtype: float64

# %%
plt.figure(figsize=(10, 6))
continent_lifeexp.plot(kind='bar', color='skyblue')
plt.title('Average Life Expectancy of Each Continent')
plt.xlabel('Continent')
plt.ylabel('Average Life Expectancy')
plt.xticks(rotation=0)
plt.show()

# %%
#Mean of the lifeExp over the years
lifeexp_avg = df_merged.groupby('year')['lifeExp'].mean()
print(lifeexp_avg)
# Out:
# year
# 1952    48.845258
# 1957    51.263281
# 1962    53.370339
# 1967    55.439087
# 1972    57.361647
# 1977    59.258698
# 1982    61.237922
# 1987    62.954125
# 1992    63.951039
# 1997    64.918328
# 2002    65.640781
# 2007    67.003922
# Name: lifeExp, dtype: float64

# %%
#plotting the average of the lifeExpectancy over the years
plt.figure(figsize=(10, 6))
lifeexp_avg.plot()
plt.title('Average Life Expectancy Over Years')
plt.xlabel('Year')
plt.ylabel('Average Life Expectancy')
plt.xticks(lifeexp_avg.index, rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 6))

# First plot - life expectancy over years as a line plot
lifeexp_avg.plot(ax=ax1, color='red', marker='o', label='Avg Life Exp Over Years')
ax1.set_xlabel('Year')
ax1.set_ylabel('Average Life Expectancy', color='red')
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_xticks(lifeexp_avg.index)
ax1.set_xticklabels(lifeexp_avg.index, rotation=45)
ax1.grid(True)

# Create a second x-axis for the continents
ax2 = ax1.twiny()  # Create a second x-axis
ax2.set_xlabel('Continent')
continent_lifeexp.plot(kind='bar', color='skyblue', ax=ax2, position=0, label='Avg Life Exp by Continent')
ax2.set_ylabel('Average Life Expectancy')
ax2.set_xticks(range(len(continent_lifeexp.index)))
ax2.set_xticklabels(continent_lifeexp.index, rotation=0)

# Adding legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('Average Life Expectancy Over Years and by Continent')
plt.show()
